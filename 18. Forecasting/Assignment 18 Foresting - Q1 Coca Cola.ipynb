# %%
# Import Libraries

import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from math import sqrt
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the data set

Data = pd.read_excel(r"D:\DS\18. Forecasting\CocaCola_Sales_Rawdata.xlsx")
Data.head()
# Out:
#   Quarter        Sales
# 0   Q1_86  1734.827000
# 1   Q2_86  2244.960999
# 2   Q3_86  2533.804993
# 3   Q4_86  2154.962997
# 4   Q1_87  1547.818996

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Quarter  42 non-null     object
#  1   Sales    42 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 800.0+ bytes

# %%
Data.shape
# Out:
# (42, 2)

# %%
# copy the orignal data

df = Data.copy()

# %%
df.head(10)
# Out:
#   Quarter        Sales
# 0   Q1_86  1734.827000
# 1   Q2_86  2244.960999
# 2   Q3_86  2533.804993
# 3   Q4_86  2154.962997
# 4   Q1_87  1547.818996
# 5   Q2_87  2104.411995
# 6   Q3_87  2014.362999
# 7   Q4_87  1991.746998
# 8   Q1_88  1869.049999
# 9   Q2_88  2313.631996

# %%
quarter=['Q1','Q2','Q3','Q4']
n=df['Quarter'][0]
n[0:2]

df['quarter']=0

# %%
for i in range(42):
    n=df['Quarter'][i]
    df['quarter'][i]=n[0:2]

# %%
dummy=pd.DataFrame(pd.get_dummies(df['quarter']))

# %%
coco=pd.concat((df,dummy),axis=1)
t= np.arange(1,43)
coco['t']=t
coco['t_square']=coco['t']*coco['t']

# %%
coco
# Out:
#    Quarter        Sales quarter  Q1  Q2  Q3  Q4   t  t_square
# 0    Q1_86  1734.827000      Q1   1   0   0   0   1         1
# 1    Q2_86  2244.960999      Q2   0   1   0   0   2         4
# 2    Q3_86  2533.804993      Q3   0   0   1   0   3         9
# 3    Q4_86  2154.962997      Q4   0   0   0   1   4        16
# 4    Q1_87  1547.818996      Q1   1   0   0   0   5        25
# 5    Q2_87  2104.411995      Q2   0   1   0   0   6        36
# 6    Q3_87  2014.362999      Q3   0   0   1   0   7        49
# 7    Q4_87  1991.746998      Q4   0   0   0   1   8        64
# 8    Q1_88  1869.049999      Q1   1   0   0   0   9        81
# 9    Q2_88  2313.631996      Q2   0   1   0   0  10       100
# 10   Q3_88  2128.320000      Q3   0   0   1   0  11       121
# 11   Q4_88  2026.828999      Q4   0   0   0   1  12       144
# 12   Q1_89  1910.603996      Q1   1   0   0   0  13       169
# 13   Q2_89  2331.164993      Q2   0   1   0   0  14       196
# 14   Q3_89  2206.549995      Q3   0   0   1   0  15       225
# 15   Q4_89  2173.967995      Q4   0   0   0   1  16       256
# 16   Q1_90  2148.278000      Q1   1   0   0   0  17       289
# 17   Q2_90  2739.307999      Q2   0   1   0   0  18       324
# 18   Q3_90  2792.753998      Q3   0   0   1   0  19       361
# 19   Q4_90  2556.009995      Q4   0   0   0   1  20       400
# 20   Q1_91  2480.973999      Q1   1   0   0   0  21       441
# 21   Q2_91  3039.522995      Q2   0   1   0   0  22       484
# 22   Q3_91  3172.115997      Q3   0   0   1   0  23       529
# 23   Q4_91  2879.000999      Q4   0   0   0   1  24       576
# 24   Q1_92  2772.000000      Q1   1   0   0   0  25       625
# 25   Q2_92  3550.000000      Q2   0   1   0   0  26       676
# 26   Q3_92  3508.000000      Q3   0   0   1   0  27       729
# 27   Q4_92  3243.859993      Q4   0   0   0   1  28       784
# 28   Q1_93  3056.000000      Q1   1   0   0   0  29       841
# 29   Q2_93  3899.000000      Q2   0   1   0   0  30       900
# 30   Q3_93  3629.000000      Q3   0   0   1   0  31       961
# 31   Q4_93  3373.000000      Q4   0   0   0   1  32      1024
# 32   Q1_94  3352.000000      Q1   1   0   0   0  33      1089
# 33   Q2_94  4342.000000      Q2   0   1   0   0  34      1156
# 34   Q3_94  4461.000000      Q3   0   0   1   0  35      1225
# 35   Q4_94  4017.000000      Q4   0   0   0   1  36      1296
# 36   Q1_95  3854.000000      Q1   1   0   0   0  37      1369
# 37   Q2_95  4936.000000      Q2   0   1   0   0  38      1444
# 38   Q3_95  4895.000000      Q3   0   0   1   0  39      1521
# 39   Q4_95  4333.000000      Q4   0   0   0   1  40      1600
# 40   Q1_96  4194.000000      Q1   1   0   0   0  41      1681
# 41   Q2_96  5253.000000      Q2   0   1   0   0  42      1764

# %%
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 250
sns.set_style('darkgrid')

# %%
plt.plot(df['Sales'])

# %%
# First-order difference
df['First-Order'] = df['Sales'].diff(periods=1)
df
# Out:
#    Quarter        Sales quarter  First-Order
# 0    Q1_86  1734.827000      Q1          NaN
# 1    Q2_86  2244.960999      Q2   510.133999
# 2    Q3_86  2533.804993      Q3   288.843994
# 3    Q4_86  2154.962997      Q4  -378.841995
# 4    Q1_87  1547.818996      Q1  -607.144001
# 5    Q2_87  2104.411995      Q2   556.592999
# 6    Q3_87  2014.362999      Q3   -90.048996
# 7    Q4_87  1991.746998      Q4   -22.616001
# 8    Q1_88  1869.049999      Q1  -122.696999
# 9    Q2_88  2313.631996      Q2   444.581997
# 10   Q3_88  2128.320000      Q3  -185.311996
# 11   Q4_88  2026.828999      Q4  -101.491001
# 12   Q1_89  1910.603996      Q1  -116.225002
# 13   Q2_89  2331.164993      Q2   420.560997
# 14   Q3_89  2206.549995      Q3  -124.614998
# 15   Q4_89  2173.967995      Q4   -32.582001
# 16   Q1_90  2148.278000      Q1   -25.689995
# 17   Q2_90  2739.307999      Q2   591.029999
# 18   Q3_90  2792.753998      Q3    53.445999
# 19   Q4_90  2556.009995      Q4  -236.744003
# 20   Q1_91  2480.973999      Q1   -75.035995
# 21   Q2_91  3039.522995      Q2   558.548996
# 22   Q3_91  3172.115997      Q3   132.593002
# 23   Q4_91  2879.000999      Q4  -293.114998
# 24   Q1_92  2772.000000      Q1  -107.000999
# 25   Q2_92  3550.000000      Q2   778.000000
# 26   Q3_92  3508.000000      Q3   -42.000000
# 27   Q4_92  3243.859993      Q4  -264.140007
# 28   Q1_93  3056.000000      Q1  -187.859993
# 29   Q2_93  3899.000000      Q2   843.000000
# 30   Q3_93  3629.000000      Q3  -270.000000
# 31   Q4_93  3373.000000      Q4  -256.000000
# 32   Q1_94  3352.000000      Q1   -21.000000
# 33   Q2_94  4342.000000      Q2   990.000000
# 34   Q3_94  4461.000000      Q3   119.000000
# 35   Q4_94  4017.000000      Q4  -444.000000
# 36   Q1_95  3854.000000      Q1  -163.000000
# 37   Q2_95  4936.000000      Q2  1082.000000
# 38   Q3_95  4895.000000      Q3   -41.000000
# 39   Q4_95  4333.000000      Q4  -562.000000
# 40   Q1_96  4194.000000      Q1  -139.000000
# 41   Q2_96  5253.000000      Q2  1059.000000

# %%
#Drop na 
df.dropna(inplace=True)

# %%
df
# Out:
#    Quarter        Sales quarter  First-Order
# 1    Q2_86  2244.960999      Q2   510.133999
# 2    Q3_86  2533.804993      Q3   288.843994
# 3    Q4_86  2154.962997      Q4  -378.841995
# 4    Q1_87  1547.818996      Q1  -607.144001
# 5    Q2_87  2104.411995      Q2   556.592999
# 6    Q3_87  2014.362999      Q3   -90.048996
# 7    Q4_87  1991.746998      Q4   -22.616001
# 8    Q1_88  1869.049999      Q1  -122.696999
# 9    Q2_88  2313.631996      Q2   444.581997
# 10   Q3_88  2128.320000      Q3  -185.311996
# 11   Q4_88  2026.828999      Q4  -101.491001
# 12   Q1_89  1910.603996      Q1  -116.225002
# 13   Q2_89  2331.164993      Q2   420.560997
# 14   Q3_89  2206.549995      Q3  -124.614998
# 15   Q4_89  2173.967995      Q4   -32.582001
# 16   Q1_90  2148.278000      Q1   -25.689995
# 17   Q2_90  2739.307999      Q2   591.029999
# 18   Q3_90  2792.753998      Q3    53.445999
# 19   Q4_90  2556.009995      Q4  -236.744003
# 20   Q1_91  2480.973999      Q1   -75.035995
# 21   Q2_91  3039.522995      Q2   558.548996
# 22   Q3_91  3172.115997      Q3   132.593002
# 23   Q4_91  2879.000999      Q4  -293.114998
# 24   Q1_92  2772.000000      Q1  -107.000999
# 25   Q2_92  3550.000000      Q2   778.000000
# 26   Q3_92  3508.000000      Q3   -42.000000
# 27   Q4_92  3243.859993      Q4  -264.140007
# 28   Q1_93  3056.000000      Q1  -187.859993
# 29   Q2_93  3899.000000      Q2   843.000000
# 30   Q3_93  3629.000000      Q3  -270.000000
# 31   Q4_93  3373.000000      Q4  -256.000000
# 32   Q1_94  3352.000000      Q1   -21.000000
# 33   Q2_94  4342.000000      Q2   990.000000
# 34   Q3_94  4461.000000      Q3   119.000000
# 35   Q4_94  4017.000000      Q4  -444.000000
# 36   Q1_95  3854.000000      Q1  -163.000000
# 37   Q2_95  4936.000000      Q2  1082.000000
# 38   Q3_95  4895.000000      Q3   -41.000000
# 39   Q4_95  4333.000000      Q4  -562.000000
# 40   Q1_96  4194.000000      Q1  -139.000000
# 41   Q2_96  5253.000000      Q2  1059.000000

# %%
# Plot
plt.plot(df['Sales'], color = 'red', label = 'Sale')
plt.plot(df['First-Order'], color = 'green', label = 'First Order')
plt.legend()

# %%
#Calculate Autocorrelation
acf_values = acf(df['First-Order'])
acf_values
# Out:
# array([ 1.        , -0.12698142, -0.58248117, -0.14078903,  0.77149614,
#        -0.14552797, -0.45200093, -0.08720848,  0.63989518, -0.10590553,
#        -0.36920089, -0.09077286,  0.53661329, -0.13653501, -0.34381079,
#        -0.04096384,  0.48023407])

# %%
#Plot ACF
plot_acf(df['First-Order'], lags=40);

# %%
#Calculate PACF
pacf_val = pacf(df['First-Order'])
pacf_val
# Out:
# array([ 1.        , -0.13015595, -0.64013685, -0.6306896 ,  0.58559493,
#        -0.39750543,  0.1046144 , -0.0772609 ,  0.18417045,  0.20544454,
#        -0.00904403,  0.06302475,  0.30259239, -0.48114516, -0.13134357,
#         0.0170421 , -0.28961627])

# %%
#Plot PACF
plot_pacf(df['First-Order'], lags=10);

# %%
coco.shape
# Out:
# (42, 9)

# %%
coco ['log_Sales'] = np.log (coco ['Sales'])

# %%
Train = coco.head(32)
Test = coco.tail(10)

# %%
Test
# Out:
#    Quarter   Sales quarter  Q1  Q2  Q3  Q4   t  t_square  log_Sales
# 32   Q1_94  3352.0      Q1   1   0   0   0  33      1089   8.117312
# 33   Q2_94  4342.0      Q2   0   1   0   0  34      1156   8.376090
# 34   Q3_94  4461.0      Q3   0   0   1   0  35      1225   8.403128
# 35   Q4_94  4017.0      Q4   0   0   0   1  36      1296   8.298291
# 36   Q1_95  3854.0      Q1   1   0   0   0  37      1369   8.256867
# 37   Q2_95  4936.0      Q2   0   1   0   0  38      1444   8.504311
# 38   Q3_95  4895.0      Q3   0   0   1   0  39      1521   8.495970
# 39   Q4_95  4333.0      Q4   0   0   0   1  40      1600   8.374015
# 40   Q1_96  4194.0      Q1   1   0   0   0  41      1681   8.341410
# 41   Q2_96  5253.0      Q2   0   1   0   0  42      1764   8.566555

# %%
from sklearn.metrics import mean_squared_error

# %%
coco.head()
# Out:
#   Quarter        Sales quarter  Q1  Q2  Q3  Q4  t  t_square  log_Sales
# 0   Q1_86  1734.827000      Q1   1   0   0   0  1         1   7.458663
# 1   Q2_86  2244.960999      Q2   0   1   0   0  2         4   7.716443
# 2   Q3_86  2533.804993      Q3   0   0   1   0  3         9   7.837477
# 3   Q4_86  2154.962997      Q4   0   0   0   1  4        16   7.675529
# 4   Q1_87  1547.818996      Q1   1   0   0   0  5        25   7.344602

# %%
Test['t']
# Out:
# 32    33
# 33    34
# 34    35
# 35    36
# 36    37
# 37    38
# 38    39
# 39    40
# 40    41
# 41    42
# Name: t, dtype: int32

# %%
#Linear Model
import statsmodels.formula.api as smf 

linear_model = smf.ols('Sales~t',data=Train).fit()
pred_linear =  pd.Series(linear_model.predict(pd.DataFrame(Test['t'])))
rmse_linear = np.sqrt(mean_squared_error(Test['Sales'], pred_linear))
rmse_linear
# Out:
# 752.9233932767132

# %%
#Exponential

Exp = smf.ols('log_Sales~t',data=Train).fit()
pred_Exp = pd.Series(Exp.predict(pd.DataFrame(Test['t'])))
rmse_Exp = np.sqrt(mean_squared_error(Test['Sales'], pred_Exp))
rmse_Exp
# Out:
# 4387.940544839098

# %%
#Quadratic 

Quad = smf.ols('Sales~t+t_square',data=Train).fit()
pred_Quad = pd.Series(Quad.predict(Test[["t","t_square"]]))
rmse_Quad = np.sqrt(mean_squared_error(Test['Sales'],pred_Quad))
rmse_Quad
# Out:
# 457.7357355407288

# %%
#Additive seasonality 

add_sea = smf.ols('Sales~Q1+Q2+Q3+Q4',data=Train).fit()
pred_add_sea = pd.Series(add_sea.predict(Test[['Q1','Q2','Q3','Q4']]))
rmse_add_sea = np.sqrt(mean_squared_error(Test['Sales'], pred_add_sea))
rmse_add_sea
# Out:
# 1850.466546185835

# %%
#Additive Seasonality Quadratic 

add_sea_Quad = smf.ols('Sales~t+t_square+Q1+Q2+Q3+Q4',data=Train).fit()
pred_add_sea_quad = pd.Series(add_sea_Quad.predict(Test[['Q1','Q2','Q3','Q4','t','t_square']]))
rmse_add_sea_quad = np.sqrt(mean_squared_error(Test['Sales'], pred_add_sea_quad))
rmse_add_sea_quad
# Out:
# 277.35107711286526

# %%
##Multiplicative Seasonality

Mul_sea = smf.ols('log_Sales~Q1+Q2+Q3+Q4',data = Train).fit()
pred_Mult_sea = pd.Series(Mul_sea.predict(Test))
rmse_Mult_sea = np.sqrt(mean_squared_error(Test['Sales'], pred_Mult_sea))
rmse_Mult_sea
# Out:
# 4388.397233580229

# %%
#Multiplicative Seasonality 

Mul_Add_sea = smf.ols('log_Sales~t+Q1+Q2+Q3+Q4',data = Train).fit()
pred_Mult_add_sea = pd.Series(Mul_Add_sea.predict(Test))
rmse_Mult_add_sea = np.sqrt(mean_squared_error(Test['Sales'], pred_Mult_add_sea))
rmse_Mult_add_sea
# Out:
# 4387.942187885532

# %%
#Compare the results 

data = {"MODEL":pd.Series(["rmse_linear","rmse_Exp","rmse_Quad","rmse_add_sea","rmse_add_sea_quad","rmse_Mult_sea","rmse_Mult_add_sea"]),"RMSE_Values":pd.Series([rmse_linear,rmse_Exp,rmse_Quad,rmse_add_sea,rmse_add_sea_quad,rmse_Mult_sea,rmse_Mult_add_sea])}
table_rmse=pd.DataFrame(data)
table_rmse.sort_values(['RMSE_Values'])
# Out:
#                MODEL  RMSE_Values
# 4  rmse_add_sea_quad   277.351077
# 2          rmse_Quad   457.735736
# 0        rmse_linear   752.923393
# 3       rmse_add_sea  1850.466546
# 1           rmse_Exp  4387.940545
# 6  rmse_Mult_add_sea  4387.942188
# 5      rmse_Mult_sea  4388.397234

# %% [markdown]
# # Moving Average

# %%
coco['Sales'].plot()
coco['Sales'].rolling(10).mean().plot()
# Out:
# <AxesSubplot:>

# %%
for i in range(2,12,4):
    coco['Sales'].rolling(i).mean().plot(label = str(i))
    plt.legend()

# %%
pip install pmdarima
# Out:
# Collecting pmdarimaNote: you may need to restart the kernel to use updated packages.
#   Downloading pmdarima-2.0.3-cp39-cp39-win_amd64.whl (572 kB)
# Requirement already satisfied: pandas>=0.19 in c:\users\vikal\anaconda3\lib\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: urllib3 in c:\users\vikal\anaconda3\lib\site-packages (from pmdarima) (1.26.9)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\vikal\anaconda3\lib\site-packages (from pmdarima) (1.7.3)
#
# Requirement already satisfied: joblib>=0.11 in c:\users\vikal\anaconda3\lib\site-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\vikal\anaconda3\lib\site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\vikal\anaconda3\lib\site-packages (from pmdarima) (61.2.0)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\vikal\anaconda3\lib\site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\vikal\anaconda3\lib\site-packages (from pmdarima) (0.29.28)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\vikal\anaconda3\lib\site-packages (from pmdarima) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\vikal\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vikal\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\vikal\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.19->pmdarima) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vikal\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\vikal\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\vikal\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\vikal\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.4)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.3

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima

# %% [markdown]
# # Check stationarity of the data

# %%
plt.plot(coco['Sales'])

# %%
print ('Results of Dickey-Fuller Test:')
dftest = adfuller(coco['Sales'], autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  1.309421
# p-value                         0.996661
# #Lags Used                      7.000000
# Number of Observations Used    34.000000
# Critical Value (1%)            -3.639224
# Critical Value (5%)            -2.951230
# Critical Value (10%)           -2.614447
# dtype: float64

# %% [markdown]
# Results of Dickey-Fuller Test:
#
# Test Statistic                  1.309421
# p-value                         0.996661
# #Lags Used                      7.000000
# Number of Observations Used    34.000000
# Critical Value (1%)            -3.639224
# Critical Value (5%)            -2.951230
# Critical Value (10%)           -2.614447
# dtype: float64
#
# If p< 0.05 ; Data is stationary
#
#
# if p>0.05; Data is not stationary
#
#
# According the p-value, the dataset is non-stationary as the p value is greater than alpha value.So, we can't build ARIMA Model.
